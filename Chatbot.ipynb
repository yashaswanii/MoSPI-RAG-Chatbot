# %%
# !pip install pandas openpyxl sqlite-utils
# !pip install sentence-transformers faiss-cpu
# !pip install transformers torch tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\jksharma\.conda\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\jksharma\.conda\lib\site-packages (3.1.5)
# Requirement already satisfied: sqlite-utils in c:\users\jksharma\.conda\lib\site-packages (3.39)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jksharma\.conda\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jksharma\.conda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jksharma\.conda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jksharma\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\jksharma\.conda\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: sqlite-fts4 in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (1.0.3)
# Requirement already satisfied: click>=8.3.1 in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (8.3.1)
# Requirement already satisfied: click-default-group>=1.2.3 in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (1.2.4)
# Requirement already satisfied: tabulate in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (0.9.0)
# Requirement already satisfied: pluggy in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (1.5.0)
# Requirement already satisfied: pip in c:\users\jksharma\.conda\lib\site-packages (from sqlite-utils) (25.1)
# Requirement already satisfied: colorama in c:\users\jksharma\.conda\lib\site-packages (from click>=8.3.1->sqlite-utils) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\jksharma\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sentence-transformers in c:\users\jksharma\.conda\lib\site-packages (5.2.0)
# Requirement already satisfied: faiss-cpu in c:\users\jksharma\.conda\lib\site-packages (1.13.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\jksharma\.conda\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jksharma\.conda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jksharma\.conda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jksharma\.conda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jksharma\.conda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jksharma\.conda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jksharma\.conda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jksharma\.conda\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\jksharma\.conda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jksharma\.conda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jksharma\.conda\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jksharma\.conda\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: transformers in c:\users\jksharma\.conda\lib\site-packages (4.57.3)
# Requirement already satisfied: torch in c:\users\jksharma\.conda\lib\site-packages (2.9.1)
# Requirement already satisfied: tqdm in c:\users\jksharma\.conda\lib\site-packages (4.67.1)
# Requirement already satisfied: filelock in c:\users\jksharma\.conda\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\jksharma\.conda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\jksharma\.conda\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jksharma\.conda\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jksharma\.conda\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jksharma\.conda\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jksharma\.conda\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\jksharma\.conda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jksharma\.conda\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: colorama in c:\users\jksharma\.conda\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jksharma\.conda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jksharma\.conda\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jksharma\.conda\lib\site-packages (from requests->transformers) (2025.4.26)

# %%
import os
import sqlite3
import pandas as pd
import numpy as np
from tqdm import tqdm

from sentence_transformers import SentenceTransformer
import faiss
from transformers import pipeline

# %%
DATA_PATH = "MoSPI_RAG_Dataset.xlsx"

df = pd.read_excel(DATA_PATH)
df.head()
# Out:
#    document_id                                             title  \
# 0            1          Press Note on Consumer Price Index (CPI)
# 1            2   Index of Industrial Production (IIP) April 2024
# 2            3  Employment Situation in India – Quarterly Report
#
#   date_published               category  \
# 0     2024-06-12    Economic Indicators
# 1     2024-05-28  Industrial Statistics
# 2     2024-03-15      Labour Statistics
#
#                                                  url  \
# 0   https://mospi.gov.in/press-release/cpi-june-2024
# 1  https://mospi.gov.in/press-release/iip-april-2024
# 2  https://mospi.gov.in/publication/employment-qu...
#
#                                              summary  \
# 0  The Consumer Price Index for June 2024 shows a...
# 1  Industrial production recorded a growth of 5.2...
# 2  This report presents key employment indicators...
#
#                                             pdf_link  \
# 0  https://mospi.gov.in/sites/default/files/repor...
# 1  https://mospi.gov.in/sites/default/files/repor...
# 2  https://mospi.gov.in/sites/default/files/repor...
#
#                                       extracted_text
# 0  The Consumer Price Index (CPI) for June 2024 i...
# 1  The Index of Industrial Production (IIP) grew ...
# 2  The quarterly employment survey indicates an i...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   document_id     3 non-null      int64
#  1   title           3 non-null      object
#  2   date_published  3 non-null      object
#  3   category        3 non-null      object
#  4   url             3 non-null      object
#  5   summary         3 non-null      object
#  6   pdf_link        3 non-null      object
#  7   extracted_text  3 non-null      object
# dtypes: int64(1), object(7)
# memory usage: 324.0+ bytes

# %%
# Rename columns (safe for SQL & pipelines)
df.columns = [col.strip().lower() for col in df.columns]

# Drop empty rows
df.dropna(subset=["title", "extracted_text"], inplace=True)

# Convert date to standard format
df["date_published"] = pd.to_datetime(df["date_published"], errors="coerce")

df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    document_id                                             title  \
# 0            1          Press Note on Consumer Price Index (CPI)
# 1            2   Index of Industrial Production (IIP) April 2024
# 2            3  Employment Situation in India – Quarterly Report
#
#   date_published               category  \
# 0     2024-06-12    Economic Indicators
# 1     2024-05-28  Industrial Statistics
# 2     2024-03-15      Labour Statistics
#
#                                                  url  \
# 0   https://mospi.gov.in/press-release/cpi-june-2024
# 1  https://mospi.gov.in/press-release/iip-april-2024
# 2  https://mospi.gov.in/publication/employment-qu...
#
#                                              summary  \
# 0  The Consumer Price Index for June 2024 shows a...
# 1  Industrial production recorded a growth of 5.2...
# 2  This report presents key employment indicators...
#
#                                             pdf_link  \
# 0  https://mospi.gov.in/sites/default/files/repor...
# 1  https://mospi.gov.in/sites/default/files/repor...
# 2  https://mospi.gov.in/sites/default/files/repor...
#
#                                       extracted_text
# 0  The Consumer Price Index (CPI) for June 2024 i...
# 1  The Index of Industrial Production (IIP) grew ...
# 2  The quarterly employment survey indicates an i...

# %%
os.makedirs("data/processed", exist_ok=True)

conn = sqlite3.connect("data/processed/mospi_documents.db")

df.to_sql(
    "documents",
    conn,
    if_exists="replace",
    index=False,
    dtype={col: "TEXT" for col in df.columns}
)

conn.close()

print("✅ Data saved to SQLite")
# Out:
# ✅ Data saved to SQLite

# %%
def chunk_text(text, chunk_size=800, overlap=200):
    words = text.split()
    chunks = []

    for i in range(0, len(words), chunk_size - overlap):
        chunk = " ".join(words[i:i + chunk_size])
        chunks.append(chunk)

    return chunks
chunks = []

for _, row in df.iterrows():
    text_chunks = chunk_text(row["extracted_text"])
    for ch in text_chunks:
        chunks.append({
            "document_id": row["document_id"],
            "title": row["title"],
            "url": row["url"],
            "chunk_text": ch
        })

chunk_df = pd.DataFrame(chunks)
chunk_df.head()
# Out:
#    document_id                                             title  \
# 0            1          Press Note on Consumer Price Index (CPI)
# 1            2   Index of Industrial Production (IIP) April 2024
# 2            3  Employment Situation in India – Quarterly Report
#
#                                                  url  \
# 0   https://mospi.gov.in/press-release/cpi-june-2024
# 1  https://mospi.gov.in/press-release/iip-april-2024
# 2  https://mospi.gov.in/publication/employment-qu...
#
#                                           chunk_text
# 0  The Consumer Price Index (CPI) for June 2024 i...
# 1  The Index of Industrial Production (IIP) grew ...
# 2  The quarterly employment survey indicates an i...

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = embedding_model.encode(
    chunk_df["chunk_text"].tolist(),
    show_progress_bar=True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\JKSharma\.conda\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\JKSharma\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)

index.add(np.array(embeddings))

print("✅ FAISS index created")
print("Total vectors:", index.ntotal)
# Out:
# ✅ FAISS index created
# Total vectors: 3

# %%
generator = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# C:\Users\JKSharma\.conda\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\JKSharma\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
def ask_question(question, top_k=3):
    # Embed question
    q_embedding = embedding_model.encode([question])

    # Retrieve top-k chunks
    distances, indices = index.search(np.array(q_embedding), top_k)

    context = ""
    citations = set()

    for idx in indices[0]:
        context += chunk_df.iloc[idx]["chunk_text"] + "\n"
        citations.add(chunk_df.iloc[idx]["url"])

    prompt = f"""
Answer strictly from the context below.
If the answer is not present, say:
"I don't have that information in my data."

Context:
{context}

Question:
{question}

Answer:
"""

    response = generator(prompt, max_length=300, do_sample=False)[0]["generated_text"]

    return response, list(citations)

# %%
answer, sources = ask_question(
    "Summarize the Index of Industrial Production report."
)

print("ANSWER:\n")
print(answer)

print("\nSOURCES:")
for s in sources:
    print(s)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=300) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ANSWER:
#
#
# Answer strictly from the context below.
# If the answer is not present, say:
# "I don't have that information in my data."
#
# Context:
# The Index of Industrial Production (IIP) grew by 5.2% in April 2024, driven by manufacturing sector growth...
# The Consumer Price Index (CPI) for June 2024 increased by 4.8 percent compared to last year...
# The quarterly employment survey indicates an improvement in labour force participation rate...
#
#
# Question:
# Summarize the Index of Industrial Production report.
#
# Answer:
#
# The Index of Industrial Production (IIP) grew by 5.2% in April 2024, driven by manufacturing sector growth...
#
# The Consumer Price Index (CPI) for June 2024 increased by 4.8 percent compared to last year...
#
# The quarterly employment survey indicates an improvement in labour force participation rate...
#
#
# Question:
#
# Summarize the Index of Industrial Production report.
#
# Answer:
#
# The Index of Industrial Production (IIP) grew by 5.2% in April 2024, driven by manufacturing sector growth...
#
# The Consumer Price Index (CPI) for June 2024 increased by 4.8 percent compared to last year...
#
# The quarterly employment survey indicates an improvement in labour force participation rate...
#
#
# Question:
#
# Summarize the Index of Industrial Production report.
#
# Answer:
#
# The Index of Industrial Production (IIP) grew by 5.2% in April 2024, driven by manufacturing sector growth...
#
# The Consumer Price Index (CPI) for June 2024 increased by 4.8 percent compared to last year...
#
# The quarterly employment survey indicates an improvement in labour force participation rate...
#
#
# Question:
#
# Summarize the Index of Industrial Production report.
#
# Answer
#
# SOURCES:
# https://mospi.gov.in/press-release/iip-april-2024
# https://mospi.gov.in/press-release/cpi-june-2024
# https://mospi.gov.in/publication/employment-quarterly-2024
